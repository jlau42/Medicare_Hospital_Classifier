# %% [markdown]
# # DSI Capstone
# ## Predicting Hospital Survey Results
#
# My goal for the capstone is to use Medicare payment and financial data to predict hospital survey results. I will use the mix of dollar spent per patient/claim as well as dollars hospitals receive from outside e.g. Research Grants, paid lunches, ect.
#
# Data for non patient care expenses will be taken from https://www.cms.gov/OpenPayments/index.html
#
# Data for Patient Surveys and Hospital spend on care will be taken from
# https://data.medicare.gov/
#
# This research will determine if patient perception of care is impacted by dollars spent on care or other incoming funds incoming to the hospital.

# %%
#!pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\jon\anaconda3\envs\dsi\lib\site-packages (0.9.2)
# Requirement already satisfied: cryptography in c:\users\jon\anaconda3\envs\dsi\lib\site-packages (from pymysql) (2.3.1)
# Requirement already satisfied: six>=1.4.1 in c:\users\jon\anaconda3\envs\dsi\lib\site-packages (from cryptography->pymysql) (1.11.0)
# Requirement already satisfied: idna>=2.1 in c:\users\jon\anaconda3\envs\dsi\lib\site-packages (from cryptography->pymysql) (2.7)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\users\jon\anaconda3\envs\dsi\lib\site-packages (from cryptography->pymysql) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in c:\users\jon\anaconda3\envs\dsi\lib\site-packages (from cryptography->pymysql) (1.11.5)
# Requirement already satisfied: pycparser in c:\users\jon\anaconda3\envs\dsi\lib\site-packages (from cffi!=1.11.3,>=1.7->cryptography->pymysql) (2.18)

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import pymysql
import seaborn as sns
import matplotlib.style as style
style.use('fivethirtyeight')
from pandas.io import sql

# %%
host="cms.ctvgwsug2thu.us-west-1.rds.amazonaws.com"
port=3306
dbname="cms"
user="bassrocker400"
password="}7n^:EU6DJs:iWN__3Ku"

conn = pymysql.connect(host, user=user,port=port,
                           passwd=password, db=dbname)

# %%
quality_fac = pd.read_sql('select * from QualityMeasures_Facility;', con=conn) 

quality_fac.head()
# Out:
#   Provider_Number                   Hospital_Name  \
# 0          010007        MIZELL MEMORIAL HOSPITAL
# 1          010008     CRENSHAW COMMUNITY HOSPITAL
# 2          010011              ST. VINCENT'S EAST
# 3          010012  DEKALB REGIONAL MEDICAL CENTER
# 4          010016   SHELBY BAPTIST MEDICAL CENTER
#
#                          Address        City State ZIP_Code County_Name  \
# 0  702 N MAIN STREET PO BOX 1010         OPP    AL    36467   Covington
# 1           101 HOSPITAL CIRCLE      LUVERNE    AL    36049    Crenshaw
# 2    50 MEDICAL PARK EAST DRIVE   BIRMINGHAM    AL    35235   Jefferson
# 3          200 MED CENTER DRIVE   FORT PAYNE    AL    35968      DeKalb
# 4       1000 FIRST STREET NORTH    ALABASTER    AL    35007      Shelby
#
#        HBIPS-2_Measure_Description HBIPS-2_Overall_Rate_Per_1000  \
# 0  Hours of physical-restraint use                 Not Available
# 1  Hours of physical-restraint use                          0.09
# 2  Hours of physical-restraint use                          0.00
# 3  Hours of physical-restraint use                          0.00
# 4  Hours of physical-restraint use                          0.03
#
#   HBIPS-2_Overall_Num ... IMM-2_Denominator IMM-2_Footnote  \
# 0                   0 ...     Not Available              1
# 1               12.15 ...               290
# 2                   0 ...               165
# 3                   0 ...                88
# 4               12.47 ...               317
#
#                       HCP_Measure_Description HCP_% HCP_Numerator  \
# 0  Healthcare Personnel Influenza Vaccination   41%            13
# 1  Healthcare Personnel Influenza Vaccination   60%            31
# 2  Healthcare Personnel Influenza Vaccination   60%           106
# 3  Healthcare Personnel Influenza Vaccination  100%            43
# 4  Healthcare Personnel Influenza Vaccination   96%            81
#
#   HCP_Denominator HCP_Footnote Flu_Season_Start_Date Flu_Season_End_Date ID
# 0              32                         10/01/2016          03/31/2017  1
# 1              52                         10/01/2016          03/31/2017  2
# 2             176                         10/01/2016          03/31/2017  3
# 3              43                         10/01/2016          03/31/2017  4
# 4              84                         10/01/2016          03/31/2017  5
#
# [5 rows x 94 columns]

# %%
quality_fac.columns
# Out:
# Index(['Provider_Number', 'Hospital_Name', 'Address', 'City', 'State',
#        'ZIP_Code', 'County_Name', 'HBIPS-2_Measure_Description',
#        'HBIPS-2_Overall_Rate_Per_1000', 'HBIPS-2_Overall_Num',
#        'HBIPS-2_Overall_Den', 'HBIPS-2_Overall_Footnote',
#        'HBIPS-3_Measure_Description', 'HBIPS-3_Overall_Rate_Per_1000',
#        'HBIPS-3_Overall_Num', 'HBIPS-3_Overall_Den',
#        'HBIPS-3_Overall_Footnote', 'HBIPS-5_Measure_Description',
#        'HBIPS-5_Overall_%_of_Total', 'HBIPS-5_Overall_Num',
#        'HBIPS-5_Overall_Den', 'HBIPS-5_Overall_Footnote',
#        'SUB-1_Measure_Description', 'SUB-1_%', 'SUB-1_Numerator',
#        'SUB-1_Denominator', 'SUB-1_Footnote', 'SUB-2/-2a_Measure_Description',
#        'SUB-2_%', 'SUB-2_Numerator', 'SUB-2_Denominator', 'SUB-2_Footnote',
#        'SUB-2a_%', 'SUB-2a_Numerator', 'SUB-2a_Denominator', 'SUB-2a_Footnote',
#        'TOB-1_Measure_Description', 'TOB-1_%', 'TOB-1_Numerator',
#        'TOB-1_Denominator', 'TOB-1_Footnote', 'TOB-2/-2a_Measure_Desc',
#        'TOB-2_%', 'TOB-2_Numerator', 'TOB-2_Denominator', 'TOB-2_Footnote',
#        'TOB-2a_%', 'TOB-2a_Numerator', 'TOB-2a_Denominator', 'TOB-2a_Footnote',
#        'TOB-3/-3a_Measure_Description', 'TOB-3_%', 'TOB-3_Numerator',
#        'TOB-3_Denominator', 'TOB-3_Footnote', 'TOB-3a_%', 'TOB-3a_Numerator',
#        'TOB-3a_Denominator', 'TOB-3a_Footnote', 'PEoC_Measure_Description',
#        'PEoC_Assessed_Response', 'PEoC_Assessed_Footnote',
#        'EHR_Use_Measure_Description', 'EHR_Use_Response', 'EHR_Use_Footnote',
#        'HIE_Measure_Description', 'HIE_Response', 'HIE_Footnote', 'Start_Date',
#        'End_Date', 'FUH_Measure_Description', 'FUH-30_%', 'FUH-30_Numerator',
#        'FUH-30_Denominator', 'FUH-30_Footnote', 'FUH-7_%', 'FUH-7_Numerator',
#        'FUH-7_Denominator', 'FUH-7_Footnote', 'FUH_Measure_Start_Date',
#        'FUH_Measure_End_Date', 'IMM-2_Measure_Description', 'IMM-2_%',
#        'IMM-2_Numerator', 'IMM-2_Denominator', 'IMM-2_Footnote',
#        'HCP_Measure_Description', 'HCP_%', 'HCP_Numerator', 'HCP_Denominator',
#        'HCP_Footnote', 'Flu_Season_Start_Date', 'Flu_Season_End_Date', 'ID'],
#       dtype='object')

# %%
survey_hospital = pd.read_sql('select * from hospital_survey;', con = conn)

survey_hospital.head()
# Out:
#   Provider ID                     Hospital Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State ZIP Code County Name Phone Number     HCAHPS Measure ID  \
# 0  DOTHAN    AL    36301     HOUSTON   3347938701         H_STAR_RATING
# 1  DOTHAN    AL    36301     HOUSTON   3347938701       H_CLEAN_HSP_A_P
# 2  DOTHAN    AL    36301     HOUSTON   3347938701      H_CLEAN_HSP_SN_P
# 3  DOTHAN    AL    36301     HOUSTON   3347938701       H_CLEAN_HSP_U_P
# 4  DOTHAN    AL    36301     HOUSTON   3347938701  H_CLEAN_LINEAR_SCORE
#
#                                      HCAHPS Question ...  \
# 0                                Summary star rating ...
# 1  Patients who reported that their room and bath... ...
# 2  Patients who reported that their room and bath... ...
# 3  Patients who reported that their room and bath... ...
# 4                    Cleanliness - linear mean score ...
#
#   HCAHPS Answer Percent HCAHPS Answer Percent Footnote  \
# 0        Not Applicable
# 1                    66
# 2                    12
# 3                    22
# 4        Not Applicable
#
#   HCAHPS Linear Mean Value Number of Completed Surveys  \
# 0           Not Applicable                         646
# 1           Not Applicable                         646
# 2           Not Applicable                         646
# 3           Not Applicable                         646
# 4                       84                         646
#
#   Number of Completed Surveys Footnote Survey Response Rate Percent  \
# 0                                                                22
# 1                                                                22
# 2                                                                22
# 3                                                                22
# 4                                                                22
#
#   Survey Response Rate Percent Footnote Measure Start Date Measure End Date ID
# 0                                               10/01/2016       09/30/2017  1
# 1                                               10/01/2016       09/30/2017  2
# 2                                               10/01/2016       09/30/2017  3
# 3                                               10/01/2016       09/30/2017  4
# 4                                               10/01/2016       09/30/2017  5
#
# [5 rows x 23 columns]

# %%
survey_hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239850 entries, 0 to 239849
# Data columns (total 23 columns):
# Provider ID                              239850 non-null object
# Hospital Name                            239850 non-null object
# Address                                  239850 non-null object
# City                                     239850 non-null object
# State                                    239850 non-null object
# ZIP Code                                 239850 non-null object
# County Name                              239850 non-null object
# Phone Number                             239850 non-null object
# HCAHPS Measure ID                        239850 non-null object
# HCAHPS Question                          239850 non-null object
# HCAHPS Answer Description                239850 non-null object
# Patient Survey Star Rating               239850 non-null object
# Patient Survey Star Rating Footnote      239850 non-null object
# HCAHPS Answer Percent                    239850 non-null object
# HCAHPS Answer Percent Footnote           239850 non-null object
# HCAHPS Linear Mean Value                 239850 non-null object
# Number of Completed Surveys              239850 non-null object
# Number of Completed Surveys Footnote     239850 non-null object
# Survey Response Rate Percent             239850 non-null object
# Survey Response Rate Percent Footnote    239850 non-null object
# Measure Start Date                       239850 non-null object
# Measure End Date                         239850 non-null object
# ID                                       239850 non-null int64
# dtypes: int64(1), object(22)
# memory usage: 42.1+ MB

# %%
survey_hospital.describe().T
# Out:
#        count      mean          std  min       25%       50%        75%  \
# ID  239850.0  119925.5  69238.87537  1.0  59963.25  119925.5  179887.75
#
#          max
# ID  239850.0

# %%
survey_hospital.columns
# Out:
# Index(['Provider ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'HCAHPS Measure ID', 'HCAHPS Question',
#        'HCAHPS Answer Description', 'Patient Survey Star Rating',
#        'Patient Survey Star Rating Footnote', 'HCAHPS Answer Percent',
#        'HCAHPS Answer Percent Footnote', 'HCAHPS Linear Mean Value',
#        'Number of Completed Surveys', 'Number of Completed Surveys Footnote',
#        'Survey Response Rate Percent', 'Survey Response Rate Percent Footnote',
#        'Measure Start Date', 'Measure End Date', 'ID'],
#       dtype='object')

# %%
question_id = pd.read_sql('select `HCAHPS Measure ID`, `HCAHPS Question` from hospital_survey group by  `HCAHPS Measure ID`', con = conn)

# %%
question_id
# Out:
#             HCAHPS Measure ID  \
# 0             H_CLEAN_HSP_A_P
# 1            H_CLEAN_HSP_SN_P
# 2             H_CLEAN_HSP_U_P
# 3        H_CLEAN_LINEAR_SCORE
# 4         H_CLEAN_STAR_RATING
# 5                H_COMP_1_A_P
# 6       H_COMP_1_LINEAR_SCORE
# 7               H_COMP_1_SN_P
# 8        H_COMP_1_STAR_RATING
# 9                H_COMP_1_U_P
# 10               H_COMP_2_A_P
# 11      H_COMP_2_LINEAR_SCORE
# 12              H_COMP_2_SN_P
# 13       H_COMP_2_STAR_RATING
# 14               H_COMP_2_U_P
# 15               H_COMP_3_A_P
# 16      H_COMP_3_LINEAR_SCORE
# 17              H_COMP_3_SN_P
# 18       H_COMP_3_STAR_RATING
# 19               H_COMP_3_U_P
# 20               H_COMP_5_A_P
# 21      H_COMP_5_LINEAR_SCORE
# 22              H_COMP_5_SN_P
# 23       H_COMP_5_STAR_RATING
# 24               H_COMP_5_U_P
# 25      H_COMP_6_LINEAR_SCORE
# 26               H_COMP_6_N_P
# 27       H_COMP_6_STAR_RATING
# 28               H_COMP_6_Y_P
# 29                 H_COMP_7_A
# 30              H_COMP_7_D_SD
# 31      H_COMP_7_LINEAR_SCORE
# 32                H_COMP_7_SA
# 33       H_COMP_7_STAR_RATING
# 34           H_HSP_RATING_0_6
# 35           H_HSP_RATING_7_8
# 36          H_HSP_RATING_9_10
# 37  H_HSP_RATING_LINEAR_SCORE
# 38   H_HSP_RATING_STAR_RATING
# 39            H_QUIET_HSP_A_P
# 40           H_QUIET_HSP_SN_P
# 41            H_QUIET_HSP_U_P
# 42       H_QUIET_LINEAR_SCORE
# 43        H_QUIET_STAR_RATING
# 44                H_RECMND_DN
# 45                H_RECMND_DY
# 46      H_RECMND_LINEAR_SCORE
# 47                H_RECMND_PY
# 48       H_RECMND_STAR_RATING
# 49              H_STAR_RATING
#
#                                       HCAHPS Question
# 0   Patients who reported that their room and bath...
# 1   Patients who reported that their room and bath...
# 2   Patients who reported that their room and bath...
# 3                     Cleanliness - linear mean score
# 4                           Cleanliness - star rating
# 5   Patients who reported that their nurses "Alway...
# 6             Nurse communication - linear mean score
# 7   Patients who reported that their nurses "Somet...
# 8                   Nurse communication - star rating
# 9   Patients who reported that their nurses "Usual...
# 10  Patients who reported that their doctors "Alwa...
# 11           Doctor communication - linear mean score
# 12  Patients who reported that their doctors "Some...
# 13                 Doctor communication - star rating
# 14  Patients who reported that their doctors "Usua...
# 15  Patients who reported that they "Always" recei...
# 16           Staff responsiveness - linear mean score
# 17  Patients who reported that they "Sometimes" or...
# 18                 Staff responsiveness - star rating
# 19  Patients who reported that they "Usually" rece...
# 20  Patients who reported that staff "Always" expl...
# 21  Communication about medicines - linear mean score
# 22  Patients who reported that staff "Sometimes" o...
# 23        Communication about medicines - star rating
# 24  Patients who reported that staff "Usually" exp...
# 25          Discharge information - linear mean score
# 26  Patients who reported that NO, they were not g...
# 27                Discharge information - star rating
# 28  Patients who reported that YES, they were give...
# 29  Patients who “Agree” they understood their car...
# 30  Patients who “Disagree” or “Strongly Disagree”...
# 31                Care transition - linear mean score
# 32  Patients who "Strongly Agree" they understood ...
# 33                      Care transition - star rating
# 34  Patients who gave their hospital a rating of 6...
# 35  Patients who gave their hospital a rating of 7...
# 36  Patients who gave their hospital a rating of 9...
# 37        Overall hospital rating - linear mean score
# 38              Overall hospital rating - star rating
# 39  Patients who reported that the area around the...
# 40  Patients who reported that the area around the...
# 41  Patients who reported that the area around the...
# 42                      Quietness - linear mean score
# 43                            Quietness - star rating
# 44  Patients who reported NO, they would probably ...
# 45  Patients who reported YES, they would definite...
# 46             Recommend hospital - linear mean score
# 47  Patients who reported YES, they would probably...
# 48                   Recommend hospital - star rating
# 49                                Summary star rating

# %%
pat_star = pd.read_sql('select * from hospital_survey \
                       where `HCAHPS Measure ID` = "H_STAR_RATING" and `Patient Survey Star Rating` <> "Not Available"', con = conn)

# %%
pat_star.head()
# Out:
#   Provider ID                     Hospital Name                     Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1      010005     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2      010006    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3      010007          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4      010011                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
#
#          City State ZIP Code County Name Phone Number HCAHPS Measure ID  \
# 0      DOTHAN    AL    36301     HOUSTON   3347938701     H_STAR_RATING
# 1        BOAZ    AL    35957    MARSHALL   2565938310     H_STAR_RATING
# 2    FLORENCE    AL    35631  LAUDERDALE   2567688400     H_STAR_RATING
# 3         OPP    AL    36467   COVINGTON   3344933541     H_STAR_RATING
# 4  BIRMINGHAM    AL    35235   JEFFERSON   2058383122     H_STAR_RATING
#
#        HCAHPS Question ...  HCAHPS Answer Percent  \
# 0  Summary star rating ...         Not Applicable
# 1  Summary star rating ...         Not Applicable
# 2  Summary star rating ...         Not Applicable
# 3  Summary star rating ...         Not Applicable
# 4  Summary star rating ...         Not Applicable
#
#   HCAHPS Answer Percent Footnote HCAHPS Linear Mean Value  \
# 0                                          Not Applicable
# 1                                          Not Applicable
# 2                                          Not Applicable
# 3                                          Not Applicable
# 4                                          Not Applicable
#
#   Number of Completed Surveys Number of Completed Surveys Footnote  \
# 0                         646
# 1                        1198
# 2                         419
# 3                         183
# 4                        2257
#
#   Survey Response Rate Percent Survey Response Rate Percent Footnote  \
# 0                           22
# 1                           34
# 2                           20
# 3                           30
# 4                           34
#
#   Measure Start Date Measure End Date   ID
# 0         10/01/2016       09/30/2017    1
# 1         10/01/2016       09/30/2017   51
# 2         10/01/2016       09/30/2017  101
# 3         10/01/2016       09/30/2017  151
# 4         10/01/2016       09/30/2017  251
#
# [5 rows x 23 columns]

# %%
# pat_star = survey_hospital[survey_hospital['HCAHPS Question'] == 'Summary star rating']
# pat_star.head()
# Out:
#     Provider ID                     Hospital Name                     Address  \
# 0        010001  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 50       010005     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 100      010006    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 150      010007          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 200      010008       CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#          City State ZIP Code County Name Phone Number HCAHPS Measure ID  \
# 0      DOTHAN    AL    36301     HOUSTON   3347938701     H_STAR_RATING
# 50       BOAZ    AL    35957    MARSHALL   2565938310     H_STAR_RATING
# 100  FLORENCE    AL    35631  LAUDERDALE   2567688400     H_STAR_RATING
# 150       OPP    AL    36467   COVINGTON   3344933541     H_STAR_RATING
# 200   LUVERNE    AL    36049    CRENSHAW   3343353374     H_STAR_RATING
#
#          HCAHPS Question ...  HCAHPS Answer Percent  \
# 0    Summary star rating ...         Not Applicable
# 50   Summary star rating ...         Not Applicable
# 100  Summary star rating ...         Not Applicable
# 150  Summary star rating ...         Not Applicable
# 200  Summary star rating ...         Not Applicable
#
#     HCAHPS Answer Percent Footnote HCAHPS Linear Mean Value  \
# 0                                            Not Applicable
# 50                                           Not Applicable
# 100                                          Not Applicable
# 150                                          Not Applicable
# 200                                          Not Applicable
#
#     Number of Completed Surveys  \
# 0                           646
# 50                         1198
# 100                         419
# 150                         183
# 200                          66
#
#                   Number of Completed Surveys Footnote  \
# 0
# 50
# 100
# 150
# 200  6 - Fewer than 100 patients completed the HCAH...
#
#     Survey Response Rate Percent  \
# 0                             22
# 50                            34
# 100                           20
# 150                           30
# 200                           30
#
#                  Survey Response Rate Percent Footnote Measure Start Date  \
# 0                                                              10/01/2016
# 50                                                             10/01/2016
# 100                                                            10/01/2016
# 150                                                            10/01/2016
# 200  6 - Fewer than 100 patients completed the HCAH...         10/01/2016
#
#     Measure End Date   ID
# 0         09/30/2017    1
# 50        09/30/2017   51
# 100       09/30/2017  101
# 150       09/30/2017  151
# 200       09/30/2017  201
#
# [5 rows x 23 columns]

# %%
# pat_star['Patient Survey Star Rating'].replace('Not Available', np.NaN, inplace = True)

# %%
pat_star['Patient Survey Star Rating'].value_counts()
# Out:
# 3    1557
# 4    1116
# 2     508
# 5     212
# 1      69
# Name: Patient Survey Star Rating, dtype: int64

# %%
plt.hist(pat_star['Patient Survey Star Rating'].astype(int), bins = 5)
# Out:
# (array([  69.,  508., 1557., 1116.,  212.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <a list of 5 Patch objects>)

# %%
spend_pat = pd.read_sql('select * from patient_spend_fac;', con=conn)
spend_pat.head(100)
# Out:
#    Provider ID                                  Hospital Name  \
# 0       010001               SOUTHEAST ALABAMA MEDICAL CENTER
# 1       010006                 ELIZA COFFEE MEMORIAL HOSPITAL
# 2       010008                    CRENSHAW COMMUNITY HOSPITAL
# 3       010012                 DEKALB REGIONAL MEDICAL CENTER
# 4       010018                          CALLAHAN EYE HOSPITAL
# 5       010021                            DALE MEDICAL CENTER
# 6       010023                   BAPTIST MEDICAL CENTER SOUTH
# 7       010029                    EAST ALABAMA MEDICAL CENTER
# 8       010033                 UNIVERSITY OF ALABAMA HOSPITAL
# 9       010035                CULLMAN REGIONAL MEDICAL CENTER
# 10      010038                 STRINGFELLOW MEMORIAL HOSPITAL
# 11      010040                GADSDEN REGIONAL MEDICAL CENTER
# 12      010045                         FAYETTE MEDICAL CENTER
# 13      010047                       GEORGIANA MEDICAL CENTER
# 14      010051                         GREENE COUNTY HOSPITAL
# 15      010055                               FLOWERS HOSPITAL
# 16      010058                            BIBB MEDICAL CENTER
# 17      010061                       HIGHLANDS MEDICAL CENTER
# 18      010065                         RUSSELL MEDICAL CENTER
# 19      010073                           CLAY COUNTY HOSPITAL
# 20      010079                      ATHENS LIMESTONE HOSPITAL
# 21      010085         DECATUR MORGAN HOSPITAL-DECATUR CAMPUS
# 22      010087     UNIVERSITY OF SOUTH ALABAMA MEDICAL CENTER
# 23      010090                            PROVIDENCE HOSPITAL
# 24      010092                  D C H REGIONAL MEDICAL CENTER
# 25      010097                      ELMORE COMMUNITY HOSPITAL
# 26      010100                                THOMAS HOSPITAL
# 27      010102                          J PAUL JONES HOSPITAL
# 28      010104                       GRANDVIEW MEDICAL CENTER
# 29      010109                  PICKENS COUNTY MEDICAL CENTER
# ..         ...                                            ...
# 70      030089              BANNER THUNDERBIRD MEDICAL CENTER
# 3         DE KALB   2568453150
# 4       JEFFERSON   2053258100
# 5            DALE   3347742601
# 6      MONTGOMERY   3342882100
# 7             LEE   3347493411
# 8       JEFFERSON   2059344011
# 9         CULLMAN   2567372000
# 10        CALHOUN   2562358900
# 11         ETOWAH   2564944000
# 12        FAYETTE   2059325966
# 13         BUTLER   3343762205
# 14         GREENE   2053723388
# 15        HOUSTON   3347935000
# 16           BIBB   2059264881
# 17        JACKSON   2562594444
# 18     TALLAPOOSA   2563297100
# 19           CLAY   2563542131
# 20      LIMESTONE   2562339292
# 21         MORGAN   2563412000
# 22         MOBILE   2514717110
# 23         MOBILE   2516331000
# 24     TUSCALOOSA   2057597111
# 25         ELMORE   3345674311
# 26        BALDWIN   2519282375
# 27         WILCOX   3346824131
# 28      JEFFERSON   2055921000
# 29        PICKENS   2053678111
# ..            ...          ...
# 70       MARICOPA   6028655555
# 71       MARICOPA   6235244000
# 72         MOHAVE   9287632273
# 73       MARICOPA   4808545050
# 74       MARICOPA   6027956020
# 75           PIMA   5208742000
# 76         NAVAJO   9283384911
# 77       MARICOPA   6233274000
# 78       MARICOPA   4807288000
# 79       MARICOPA   4803586100
# 80       MARICOPA   4803247001
# 81       MARICOPA   6027977700
# 82          PINAL   4807333300
# 83           PIMA   5203934710
# 84        COCHISE   5205862261
# 85       COCONINO   9286452424
# 86         LA PAZ   9286692137
# 87         APACHE   9287554541
# 88        COCHISE   5204326401
# 89           GILA   9284021122
# 90         LA PAZ   9286699201
# 91       MARICOPA   6022434231
# 92        JOHNSON   4797545454
# 93        PULASKI   5015523000
# 94           YELL   4794952241
# 95           POLK   4793946100
# 96          BOONE   8704144000
# 97  SAINT FRANCIS   8702610000
# 98     WASHINGTON   4797515711
# 99         BAXTER   8705081000
#
#                                          Measure Name Measure ID  \
# 0   Medicare hospital spending per patient (Medica...     MSPB_1
# 1   Medicare hospital spending per patient (Medica...     MSPB_1
# 2   Medicare hospital spending per patient (Medica...     MSPB_1
# 3   Medicare hospital spending per patient (Medica...     MSPB_1
# 4   Medicare hospital spending per patient (Medica...     MSPB_1
# 5   Medicare hospital spending per patient (Medica...     MSPB_1
# 6   Medicare hospital spending per patient (Medica...     MSPB_1
# 7   Medicare hospital spending per patient (Medica...     MSPB_1
# 8   Medicare hospital spending per patient (Medica...     MSPB_1
# 9   Medicare hospital spending per patient (Medica...     MSPB_1
# 10  Medicare hospital spending per patient (Medica...     MSPB_1
# 11  Medicare hospital spending per patient (Medica...     MSPB_1
# 12  Medicare hospital spending per patient (Medica...     MSPB_1
# 13  Medicare hospital spending per patient (Medica...     MSPB_1
# 14  Medicare hospital spending per patient (Medica...     MSPB_1
# 15  Medicare hospital spending per patient (Medica...     MSPB_1
# 16  Medicare hospital spending per patient (Medica...     MSPB_1
# 17  Medicare hospital spending per patient (Medica...     MSPB_1
# 18  Medicare hospital spending per patient (Medica...     MSPB_1
# 19  Medicare hospital spending per patient (Medica...     MSPB_1
# 20  Medicare hospital spending per patient (Medica...     MSPB_1
# 21  Medicare hospital spending per patient (Medica...     MSPB_1
# 22  Medicare hospital spending per patient (Medica...     MSPB_1
# 23  Medicare hospital spending per patient (Medica...     MSPB_1
# 24  Medicare hospital spending per patient (Medica...     MSPB_1
# 25  Medicare hospital spending per patient (Medica...     MSPB_1
# 26  Medicare hospital spending per patient (Medica...     MSPB_1
# 27  Medicare hospital spending per patient (Medica...     MSPB_1
# 28  Medicare hospital spending per patient (Medica...     MSPB_1
# 29  Medicare hospital spending per patient (Medica...     MSPB_1
# ..                                                ...        ...
# 70  Medicare hospital spending per patient (Medica...     MSPB_1
# 71  Medicare hospital spending per patient (Medica...     MSPB_1
# 72  Medicare hospital spending per patient (Medica...     MSPB_1
# 73  Medicare hospital spending per patient (Medica...     MSPB_1
# 74  Medicare hospital spending per patient (Medica...     MSPB_1
# 75  Medicare hospital spending per patient (Medica...     MSPB_1
# 76  Medicare hospital spending per patient (Medica...     MSPB_1
# 77  Medicare hospital spending per patient (Medica...     MSPB_1
# 78  Medicare hospital spending per patient (Medica...     MSPB_1
# 79  Medicare hospital spending per patient (Medica...     MSPB_1
# 80  Medicare hospital spending per patient (Medica...     MSPB_1
# 81  Medicare hospital spending per patient (Medica...     MSPB_1
# 82  Medicare hospital spending per patient (Medica...     MSPB_1
# 83  Medicare hospital spending per patient (Medica...     MSPB_1
# 84  Medicare hospital spending per patient (Medica...     MSPB_1
# 85  Medicare hospital spending per patient (Medica...     MSPB_1
# 86  Medicare hospital spending per patient (Medica...     MSPB_1
# 87  Medicare hospital spending per patient (Medica...     MSPB_1
# 88  Medicare hospital spending per patient (Medica...     MSPB_1
# 89  Medicare hospital spending per patient (Medica...     MSPB_1
# 90  Medicare hospital spending per patient (Medica...     MSPB_1
# 91  Medicare hospital spending per patient (Medica...     MSPB_1
# 92  Medicare hospital spending per patient (Medica...     MSPB_1
# 93  Medicare hospital spending per patient (Medica...     MSPB_1
# 94  Medicare hospital spending per patient (Medica...     MSPB_1
# 95  Medicare hospital spending per patient (Medica...     MSPB_1
# 96  Medicare hospital spending per patient (Medica...     MSPB_1
# 97  Medicare hospital spending per patient (Medica...     MSPB_1
# 98  Medicare hospital spending per patient (Medica...     MSPB_1
# 99  Medicare hospital spending per patient (Medica...     MSPB_1
#
#             Score                                           Footnote  \
# 0            0.99
# 1               1
# 2            0.92
# 3            0.97
# 4            1.01
# 5            0.95
# 6            1.02
# 7            0.92
# 8            0.97
# 9            0.96
# 10           0.98
# 11           1.04
# 12           0.92
# 13           0.91
# 14           0.86
# 15           1.03
# 16           1.02
# 17           0.99
# 18           0.98
# 19           0.97
# 20           0.96
# 21              1
# 22           0.94
# 23           0.99
# 24              1
# 25           1.03
# 26           0.94
# 27              1
# 28           1.02
# 29           0.85
# ..            ...                                                ...
# 70           1.01
# 71           0.94
# 72            0.9
# 73           1.01
# 74           0.86
# 75           0.91
# 76           0.71
# 77           0.93
# 78              1
# 79           1.03
# 80           0.96
# 81           0.97
# 82           0.81
# 83           0.91
# 84  Not Available  5 - Results are not available for this reporti...
# 85         01/01/2016  12/31/2016"\r\n"031305   86
# 86         01/01/2016  12/31/2016"\r\n"031308   87
# 87         01/01/2016  12/31/2016"\r\n"031311   88
# 88         01/01/2016  12/31/2016"\r\n"031313   89
# 89         01/01/2016  12/31/2016"\r\n"031315   90
# 90         01/01/2016  12/31/2016"\r\n"033302   91
# 91         01/01/2016  12/31/2016"\r\n"040001   92
# 92         01/01/2016  12/31/2016"\r\n"040004   93
# 93         01/01/2016  12/31/2016"\r\n"040010   94
# 94         01/01/2016  12/31/2016"\r\n"040014   95
# 95         01/01/2016  12/31/2016"\r\n"040016   96
# 96         01/01/2016  12/31/2016"\r\n"040018   97
# 97         01/01/2016  12/31/2016"\r\n"040020   98
# 98         01/01/2016  12/31/2016"\r\n"040026   99
# 99         01/01/2016  12/31/2016"\r\n"040029  100
#
# [100 rows x 15 columns]

# %%
spend_pat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 15 columns):
# Provider ID           2399 non-null object
# Hospital Name         2399 non-null object
# Address               2399 non-null object
# City                  2399 non-null object
# State                 2399 non-null object
# ZIP Code              2399 non-null object
# County Name           2399 non-null object
# Phone Number          2399 non-null object
# Measure Name          2399 non-null object
# Measure ID            2399 non-null object
# Score                 1561 non-null float64
# Footnote              2399 non-null object
# Measure Start Date    2399 non-null object
# Measure End Date      2399 non-null object
# ID                    2399 non-null int64
# dtypes: float64(1), int64(1), object(13)
# memory usage: 281.2+ KB

# %%
spend_pat['Score'].value_counts()

# %%
spend_pat['Score'] = spend_pat['Score'].convert_objects(convert_numeric=True)
# Out:
# c:\users\jon\anaconda3\envs\dsi\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
spend_pat['Score'].hist()

# %%
spend_pat['Score'].value_counts()
# Out:
# 1.00    104
# 0.97     92
# 1.02     88
# 0.99     85
# 1.03     83
# 0.94     83
# 1.01     82
# 0.98     81
# 0.96     80
# 0.95     69
# 0.93     68
# 1.04     64
# 1.05     56
# 0.91     46
# 0.92     44
# 1.06     43
# 1.07     39
# 0.89     34
# 0.90     33
# 0.88     24
# 1.08     22
# 0.87     22
# 1.09     21
# 0.85     19
# 1.10     18
# 1.11     15
# 0.86     14
# 0.84     13
# 1.12     12
# 0.82      8
#        ...
# 1.13      4
# 0.76      4
# 1.20      4
# 0.78      4
# 0.74      3
# 0.79      3
# 0.71      3
# 0.67      3
# 1.18      3
# 0.80      3
# 1.22      3
# 1.32      2
# 1.27      2
# 0.75      2
# 1.30      1
# 0.68      1
# 0.62      1
# 1.34      1
# 1.37      1
# 1.24      1
# 0.73      1
# 0.69      1
# 1.44      1
# 0.72      1
# 1.55      1
# 0.70      1
# 2.63      1
# 1.19      1
# 1.40      1
# 1.36      1
# Name: Score, Length: 67, dtype: int64

# %% [markdown]
# # MSPB Calculation
# - ### Properties
#
# Description The Medicare Spending Per Beneficiary (MSPB) Measure evaluates solo
# practitioners and
# groups of practitioners (including physicians) on their efficiency and is
# specialty-adjusted to
# account for the group’s specialty mix. Solo practitioners and groups of
# practitioners (including
# physicians) are identified by their Taxpayer Identification Number (TIN).
# Specifically, the
# MSPB Measure assesses the cost to Medicare of services performed by TINs
# during an MSPB
# episode, which comprises the period immediately prior to,
# during, and following
# a patient’s
# hospital stay
# - ### Numerator
#
# The numerator for a TIN s specialty-adjusted MSPB Measure is the TIN s
# average MSPB Amount, which is defined as the sum of standardized, riskadjusted
# spending across all of a TIN s eligible episodes divided by the
# number of episodes for that TIN. This ratio is multiplied by the national average
# standardized episode cost. An MSPB episode includes all Medicare Part A and
# Part B claims with a start date falling between 3 days prior to an Inpatient
# Prospective Payment System (IPPS) hospital admission (also known as the
# index admission for the episode) through 30 days post-hospital discharge.
# - ### Denominator
#
# The denominator for a TIN s MSPB Measure is the specialty-adjusted MSPB
# expected cost based on the national specialty-specific expected cost of the
# specialties represented by the TIN s eligible professionals (EPs). Methodology
# for specialty-adjustment is discussed in the Specialty adjustment sectionbelow. Beneficiary populations eligible to be included in the MSPB Measure
# are made up of beneficiaries who were enrolled in both Medicare Parts A and
# B for the period 93 days prior to IPPS hospital admission until 30 days after
# discharge from a short-term acute care hospital stay, where the stay occurs
# during the period of performance. Defining the population in this manner
# ensures that each beneficiary s claims record contains sufficient fee-for-service
# (FFS) data both for measuring spending levels and for risk adjustment
# purposes. Only claims for beneficiaries admitted to subsection (d) hospitals
# during the period of performance are included in the calculation of the MSPB
# Measure. Subsection (d) hospitals are hospitals in the 50 States and D.C.
# other than: psychiatric hospitals, rehabilitation hospitals, hospitals whose
# inpatients are predominantly under 18 years old, hospitals whose average
# inpatient length of stay exceeds 25 days, and hospitals involved extensively in
# treatment for or research on cancer. The claims for inpatient admissions to
# subsection (d) hospitals are grouped into stays by beneficiary, admission date,
# and provider.
#
# - ### Denominator Exclusions
#
# Beneficiary populations excluded from the MSPB calculation are those with
# episodes where
# at any time 93 days before admission through 30 days post-discharge, the
# beneficiary is enrolled
# in a Medicare Advantage plan, or Medicare is the secondary payer. Episodes
# where the
# beneficiary becomes deceased during the episode are also excluded.
# Regarding beneficiaries
# whose primary insurance becomes Medicaid during an episode due to
# exhaustion of Medicare
# Part A benefits, Medicaid payments made for services rendered to these
# beneficiaries are
# excluded, however, all Medicare Part A payments made before benefits are
# exhausted and all
# Medicare Part B payments made during the episode are included.
# Further, any episode in which the index admission inpatient claim has a 0
# actual payment or a 0 standardized payment is excluded. In addition, acute-to-acute transfers
# (where a transfer
# is defined based on the claim discharge code) are not considered index
# admissions. In other words, these cases do not generate new MSPB episodes, neither the hospital
# which transfers a
# patient to another subsection (d) hospital, nor the receiving subsection (d)
# hospital will have an
# index admission or associated MSPB episode attributed to them.
# Admissions to hospitals that Medicare does not reimburse through the IPPS
# system (e.g.,
# cancer hospitals, critical access hospitals, hospitals in Maryland) are not
# considered index
# admissions and are therefore not eligible to begin an MSPB episode. If an
# acute-to-acute
# hospital transfer or a hospitalization in a PPS-exempt hospital happens during
# the 30-days
# following discharge from an index admission, however, these post-discharge
# costs will count
# toward in the measure.
#
# https://cmit.cms.gov/CMIT_public/ViewMeasure?MeasureId=1643
